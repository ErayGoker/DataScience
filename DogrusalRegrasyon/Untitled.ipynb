# %%
import pandas as pd 
import numpy as np
from sklearn.linear_model import LinearRegression

# %%
train=pd.read_csv("train.csv")
test=pd.read_csv("test.csv")
train
# Out:
#      OverallQual  YearBuilt  YearRemodAdd  TotalBsmtSF  1stFlrSF  GrLivArea  \
# 0              6       1969          1969          663       663       1352
# 1              6       1920          1950         1012      1012       1012
# 2              5       1910          2006         1022      1022       1022
# 3              5       1973          1973         1656      1656       1656
# 4              6       1978          1978          918       918       1683
# ..           ...        ...           ...          ...       ...        ...
# 760            6       2000          2000          959       959       1671
# 761            7       2002          2002         1459      1459       1459
# 762            5       1955          1990          864       864        864
# 763            5       1956          1956         1048      1048       1048
# 764            7       2006          2007         1258      1402       1402
#
# ...

# %%
test
# Out:
#      OverallQual  YearBuilt  YearRemodAdd  TotalBsmtSF  1stFlrSF  GrLivArea  \
# 0              4       1961          1961         1029      1029       1029
# 1              5       1921          1950          731       820       1343
# 2              7       1998          1998          723       767        767
# 3              4       1955          1955         1005      1005       1005
# 4              6       1963          2003         1059      1068       1068
# ..           ...        ...           ...          ...       ...        ...
# 324            4       1963          1963         1064      1040       1040
# 325            5       1972          1972          894       894        894
# 326            8       1983          2009         1496      1496       2132
# 327            6       1961          1996          912       912        912
# 328            8       2003          2004         1053      1053       1992
#
# ...

# %%
model=LinearRegression()
xTrain=train.drop("SalePrice",axis=1)
yTrain=train.loc[:,"SalePrice"]
model.fit(xTrain,yTrain)
# Out:
# LinearRegression()

# %%
xTest=test.drop("SalePrice",axis=1)
yTest=test.loc[:,"SalePrice"]
yTest
# Out:
# 0      118500
# 1      154900
# 2      133000
# 3      115000
# 4      154500
#         ...
# 324    132250
# 325    123000
# 326    316600
# 327    142000
# 328    250000
# Name: SalePrice, Length: 329, dtype: int64

# %%
tahminler=model.predict(xTest)

# %%
from sklearn.metrics import mean_squared_error

# %%
hataOrani=np.sqrt(mean_squared_error(yTest,tahminler))
hataOrani
# Out:
# 33186.38417236771

# %%
karsilastirmaTablosu=pd.DataFrame({"gercekDegerler":yTest,"tahminler":tahminler})
karsilastirmaTablosu
# Out:
#      gercekDegerler      tahminler
# 0            118500   83380.944694
# 1            154900  105974.149765
# 2            133000  139238.138343
# 3            115000  104982.049557
# 4            154500  140473.360146
# ..              ...            ...
# 324          132250  102816.796295
# 325          123000  121698.649065
# 326          316600  271745.844407
# 327          142000  131258.275591
# 328          250000  263005.372419
#
# [329 rows x 2 columns]

# %%
train.corr()["SalePrice"].sort_values(ascending=False).head(10)
# Out:
# SalePrice           1.000000
# OverallQual         0.792263
# GrLivArea           0.712054
# GarageCars          0.658355
# GarageArea          0.621354
# 1stFlrSF            0.621057
# TotalBsmtSF         0.612205
# FullBath            0.597505
# TotRmsAbvGrd        0.573845
# Foundation_PConc    0.517222
# Name: SalePrice, dtype: float64
