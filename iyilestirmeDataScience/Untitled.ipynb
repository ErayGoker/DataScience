# %%
import pandas as pd 
import numpy as np 
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression,Ridge
from sklearn.metrics import mean_squared_error

# %%
train=pd.read_csv("train.csv")

# %%
train
# Out:
#      OverallQual  YearBuilt  YearRemodAdd  TotalBsmtSF  1stFlrSF  GrLivArea  \
# 0              6       1969          1969          663       663       1352
# 1              6       1920          1950         1012      1012       1012
# 2              5       1910          2006         1022      1022       1022
# 3              5       1973          1973         1656      1656       1656
# 4              6       1978          1978          918       918       1683
# ..           ...        ...           ...          ...       ...        ...
# 760            6       2000          2000          959       959       1671
# 761            7       2002          2002         1459      1459       1459
# 762            5       1955          1990          864       864        864
# 763            5       1956          1956         1048      1048       1048
# 764            7       2006          2007         1258      1402       1402
#
# ...

# %%
train,test=train_test_split(train,test_size=0.2)

# %%
test
# Out:
#      OverallQual  YearBuilt  YearRemodAdd  TotalBsmtSF  1stFlrSF  GrLivArea  \
# 591            7       1967          2007          710      1898       2978
# 275            4       1963          1979         1051      1382       1382
# 692            7       1930          1950          637      1108       1108
# 106            5       1925          1950          768      1015       1015
# 168            6       2009          2009         1218      1218       1218
# ..           ...        ...           ...          ...       ...        ...
# 241            5       1948          2001          672      1072       1285
# 384            5       1939          1950          793       793       1118
# 469            8       2000          2000         1145      1145       2198
# 326            5       1960          1960         1065      1065       1065
# 120            9       2004          2005         1833      1850       1850
#
# ...

# %%
train
# Out:
#      OverallQual  YearBuilt  YearRemodAdd  TotalBsmtSF  1stFlrSF  GrLivArea  \
# 381            6       1959          2006         1019      1357       1357
# 495            6       1953          1953         1505      1505       1505
# 746            7       2005          2006         1552      1552       1552
# 659            6       2004          2004          848       848        848
# 553            5       1965          1965          828       965        965
# ..           ...        ...           ...          ...       ...        ...
# 431            4       1920          1950          698       698       1128
# 619            9       2007          2007         1822      1828       1828
# 287            7       2004          2005         1860      1836       1836
# 350            6       1950          2001         1202      2158       2158
# 182            7       2006          2007          625       625       1250
#
# ...

# %%
xTrain=train.drop("SalePrice",axis=1)
yTrain=train.loc[:,"SalePrice"]

# %%
xTest=test.drop("SalePrice",axis=1)
yTest=test.loc[:,"SalePrice"]

# %%
model1=LinearRegression()
model1.fit(xTrain,yTrain)
tahminler=model1.predict(xTest)
mean_squared_error(yTest,tahminler)
# Out:
# 1436256385.12852

# %%
model2=Ridge(alpha=5)
model2.fit(xTrain,yTrain)
tahminler2=model2.predict(xTest)
mean_squared_error(yTest,tahminler2)
# Out:
# 1431454914.9955552
